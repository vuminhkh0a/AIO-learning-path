# %%
from abc import ABC, abstractmethod

#1
class Person:
    def __init__(self, name, yob):
        self.name = name
        self.yob = yob
    
    def get_age(self):
        return self.yob
    
    @abstractmethod
    def describe(self):
        pass

    

class Student(Person):
    def __init__(self, name, yob, grade):
        super().__init__(name, yob)
        self.grade = grade

    def describe(self):
        print(f'Student - Name: {self.name} - YoB: {self.yob} - Grade: {self.grade}')

class Teacher(Person):
    def __init__(self, name, yob, subject):
        super().__init__(name, yob)
        self.subject = subject

    def describe(self):
        print(f'Student - Name: {self.name} - YoB: {self.yob} - Subject: {self.subject}')

class Doctor(Person):
    def __init__(self, name, yob, specialist):
        super().__init__(name, yob)
        self.specialist = specialist

    def describe(self):
        print(f'Student - Name: {self.name} - YoB: {self.yob} - Specialist: {self.specialist}')

# %%
#2
class Ward:
    def __init__(self, ward_name):
        self.ward_name = ward_name
        self.person_list = []
    
    def add_person(self, person):
        self.person_list.append(person)
    
    def describe(self):
        print(self.ward_name)
        for person in self.person_list:
            person.describe()

    def CountDoctor(self):
        count_doctor = 0
        for person in self.person_list:
            if isinstance(person, Doctor):
                count_doctor += 1
        return count_doctor
    
    def CountTeacher(self):
        count_teacher = 0
        for person in self.person_list:
            if isinstance(person, Teacher):
                count_teacher += 1
        return count_teacher

    def sort_age(self):
        for i in range(len(self.person_list)):
            for j in range(i, len(self.person_list)):
                if self.person_list[j].get_age() < self.person_list[i].get_age():
                    tmp = self.person_list[i]
                    self.person_list[i] = self.person_list[j]
                    self.person_list[j] = tmp
    
    def aveTeacherYearOfBirth(self):
        return sum([person.get_age() for person in self.person_list if isinstance(person, Teacher)]) / ward1.CountTeacher()

ward1 = Ward('Ward 1')

student1 = Student('Student 1', 2006, 4.0)
teacher1 = Teacher('Teacher 1', 2001, 'Math')
teacher2 = Teacher('Teacher 2', 1980, 'Literature')
doctor1 = Doctor('Doctor 1', 1960, 'Heart')
doctor2 = Doctor('Doctor 2', 1969, 'Eyes')

ward1.add_person(student1)
ward1.add_person(teacher1)
ward1.add_person(teacher2)
ward1.add_person(doctor1)
ward1.add_person(doctor2)

ward1.describe()

print('Number of doctor:', ward1.CountDoctor())

ward1.sort_age()
ward1.describe()

print('Average YOB of teachers:', ward1.aveTeacherYearOfBirth())
# Out:
# Ward 1
# Student - Name: Student 1 - YoB: 2006 - Grade: 4.0
# Student - Name: Teacher 1 - YoB: 2001 - Subject: Math
# Student - Name: Teacher 2 - YoB: 1980 - Subject: Literature
# Student - Name: Doctor 1 - YoB: 1960 - Specialist: Heart
# Student - Name: Doctor 2 - YoB: 1969 - Specialist: Eyes
# Number of doctor: 2
# Ward 1
# Student - Name: Doctor 1 - YoB: 1960 - Specialist: Heart
# Student - Name: Doctor 2 - YoB: 1969 - Specialist: Eyes
# Student - Name: Teacher 2 - YoB: 1980 - Subject: Literature
# Student - Name: Teacher 1 - YoB: 2001 - Subject: Math
# Student - Name: Student 1 - YoB: 2006 - Grade: 4.0
# Average YOB of teachers: 1990.5
